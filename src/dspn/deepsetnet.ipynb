# %%
  
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
class deepsetnet(nn.Module): 
    def __init__(self, encoder, latent_dim, set_dim, n_iters):
        self.Y0 = nn.Parameters(torch.randn(set_dim))/10
        self.encoder = encoder 
        self.set_dim = set_dim 
        self.latent_dim = latent_dim 
        self.loss = loss 
        self.n_iters = n_iters
        self.learn_rate = 800
        
    def forward(self, x): 
        y = self.Y0 
        
        loss_func = nn.MSELoss(reduction = 'sum')
        with torch.enable_grad: 
            
            for i in range(n_iters): 
                optimizer.zero_grad() 
                output = self.encoder(y)
                loss = loss_func(output, target)
                output_grad = torch.autograd.grad(y,loss)
                y = y - learn_rate*output_grad 
                
        return y

# %%
def chamfer_loss(output, target): 
    diff_mat  = [[sum((i-j)**2) for i in output] for j in target] 
    diff_mat = torch.float_tensor(diff_mat)
    min1 = diff_mat.min(0)
    min2 = diff_mat.min(1)
    return sum(min1) + sum(min2)

# %%
kronecker(a,b)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-7c9b2e1f7b87> in <module>
# ----> 1 kronecker(a,b)
#
# <ipython-input-12-f852271a1749> in kronecker(matrix1, matrix2)
#       1 def kronecker(matrix1, matrix2):
# ----> 2     return torch.ger(matrix1.view(-1), matrix2.view(-1)).reshape(*(matrix1.size() + matrix2.size())).permute([0, 2, 1, 3]).reshape(matrix1.size(0) * matrix2.size(0), matrix1.size(1) * matrix2.size(1))
#
# RuntimeError: number of dims don't match in permute

# %%
def kronecker(matrix1, matrix2):
    return torch.ger(matrix1.view(-1), matrix2.view(-1)).reshape(*(matrix1.size() + matrix2.size())).permute([0, 2, 1, 3]).reshape(matrix1.size(0) * matrix2.size(0), matrix1.size(1) * matrix2.size(1))

# %%
a.min(1)[0]
# Out:
# tensor([-0.2784, -0.6350, -0.4636])
